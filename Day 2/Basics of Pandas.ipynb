# %%
import pandas as pd

# %%
#Setting the path

# %%
#To Check your working directory

# %%
cd
# Out:
# /Users/kantha

# %%
cd Regression
# Out:
# /Users/kantha/Downloads/Regression

# %%
company = pd.read_csv('Company_Data (1).csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-86aada4f6878> in <module>
# ----> 1 company = pd.read_csv('Company_Data (1).csv')
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
company
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0     9.50        138      73           11         276    120   42         17
# 1    11.22        111      48           16         260     83   65         10
# 2    10.06        113      35           10         269     80   59         12
# 3     7.40        117     100            4         466     97   55         14
# 4     4.15        141      64            3         340    128   38         13
# ..     ...        ...     ...          ...         ...    ...  ...        ...
# 395  12.57        138     108           17         203    128   33         14
# 396   6.14        139      23            3          37    120   55         11
# 397   7.41        162      26           12         368    159   40         18
# 398   5.94        100      79            7         284     95   50         12
# 399   9.71        134      37            0          27    120   49         16
#
#     Urban   US
# 0     Yes  Yes
# ...

# %%
#Printing first 5 Rows
company.head(10)
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0   9.50        138      73           11         276    120   42         17
# 1  11.22        111      48           16         260     83   65         10
# 2  10.06        113      35           10         269     80   59         12
# 3   7.40        117     100            4         466     97   55         14
# 4   4.15        141      64            3         340    128   38         13
# 5  10.81        124     113           13         501     72   78         16
# 6   6.63        115     105            0          45    108   71         15
# 7  11.85        136      81           15         425    120   67         10
# 8   6.54        132     110            0         108    124   76         10
# 9   4.69        132     113            0         131    124   76         17
#
#   Urban   US
# 0   Yes  Yes
# 1   Yes  Yes
# 2   Yes  Yes
# 3   Yes  Yes
# 4   Yes   No
# 5    No  Yes
# 6   Yes   No
# 7   Yes  Yes
# ...

# %%
company.tail(10) #printing last 5 rows
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 390   5.47        108      75            9          61    111   67         12
# 391   6.10        153      63            0          49    124   56         16
# 392   4.53        129      42           13         315    130   34         13
# 393   5.57        109      51           10          26    120   30         17
# 394   5.35        130      58           19         366    139   33         16
# 395  12.57        138     108           17         203    128   33         14
# 396   6.14        139      23            3          37    120   55         11
# 397   7.41        162      26           12         368    159   40         18
# 398   5.94        100      79            7         284     95   50         12
# 399   9.71        134      37            0          27    120   49         16
#
#     Urban   US
# 390   Yes  Yes
# 391   Yes   No
# 392   Yes  Yes
# 393    No  Yes
# 394   Yes  Yes
# ...

# %%
company.describe() #Describing the dataset
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# ...

# %%
company.Sales.describe()
# Out:
# count    400.000000
# mean       7.496325
# std        2.824115
# min        0.000000
# 25%        5.390000
# 50%        7.490000
# 75%        9.320000
# max       16.270000
# Name: Sales, dtype: float64

# %%
#checking complete information about the dataset
company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 10 columns):
# Sales          400 non-null float64
# CompPrice      400 non-null int64
# Income         400 non-null int64
# Advertising    400 non-null int64
# Population     400 non-null int64
# Price          400 non-null int64
# Age            400 non-null int64
# Education      400 non-null int64
# Urban          400 non-null object
# US             400 non-null object
# dtypes: float64(1), int64(7), object(2)
# memory usage: 31.4+ KB

# %%
company.shape #used to check the shape of the dataset
# Out:
# (400, 10)

# %%
company.shape[0] #printing number of rows
# Out:
# 400

# %%
company.shape[1] #printing number of columns
# Out:
# 10

# %%
#Need to print the columns
company.columns
# Out:
# Index(['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price',
#        'Age', 'Education', 'Urban', 'US'],
#       dtype='object')

# %%
#need to select only sales column
company['Sales']
# Out:
# 0       9.50
# 1      11.22
# 2      10.06
# 3       7.40
# 4       4.15
#        ...
# 395    12.57
# 396     6.14
# 397     7.41
# 398     5.94
# 399     9.71
# Name: Sales, Length: 400, dtype: float64

# %%
company.Sales
# Out:
# 0       9.50
# 1      11.22
# 2      10.06
# 3       7.40
# 4       4.15
#        ...
# 395    12.57
# 396     6.14
# 397     7.41
# 398     5.94
# 399     9.71
# Name: Sales, Length: 400, dtype: float64

# %%
#Creating a new column in existing dataset
company['Profit'] = company['Income']-company['Price']

# %%
company.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0   9.50        138      73           11         276    120   42         17
# 1  11.22        111      48           16         260     83   65         10
# 2  10.06        113      35           10         269     80   59         12
# 3   7.40        117     100            4         466     97   55         14
# 4   4.15        141      64            3         340    128   38         13
#
#   Urban   US  Profit
# 0   Yes  Yes     -47
# 1   Yes  Yes     -35
# 2   Yes  Yes     -45
# 3   Yes  Yes       3
# 4   Yes   No     -64

# %%
#I want to pick a sample
sample_company = company.sample(n= 100)

# %%
sample_company.head()
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 246   6.90        120      56           20         266     90   78         18
# 50    1.42         99      32           18         341    108   80         16
# 70    9.46         89      81           15         237     99   74         12
# 261   5.71        121      42            4         188    118   54         15
# 344   8.43        138      80            0         108    126   70         13
#
#     Urban   US  Profit
# 246   Yes  Yes     -34
# 50    Yes  Yes     -76
# 70    Yes  Yes     -18
# 261   Yes  Yes     -76
# 344    No  Yes     -46

# %%
sample_company.shape
# Out:
# (100, 11)

# %%
sample_company = company.sample(frac = 0.35)

# %%
sample_company.shape
# Out:
# (140, 11)

# %%
#Indexing
company.iloc[:,:]
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0     9.50        138      73           11         276    120   42         17
# 1    11.22        111      48           16         260     83   65         10
# 2    10.06        113      35           10         269     80   59         12
# 3     7.40        117     100            4         466     97   55         14
# 4     4.15        141      64            3         340    128   38         13
# ..     ...        ...     ...          ...         ...    ...  ...        ...
# 395  12.57        138     108           17         203    128   33         14
# 396   6.14        139      23            3          37    120   55         11
# 397   7.41        162      26           12         368    159   40         18
# 398   5.94        100      79            7         284     95   50         12
# 399   9.71        134      37            0          27    120   49         16
#
#     Urban   US  Profit
# ...

# %%
company.iloc[1,2]
# Out:
# 48

# %%
company.iloc[:2,1]
# Out:
# 0    138
# 1    111
# Name: CompPrice, dtype: int64

# %%
company.iloc[:3, 6:]
# Out:
#    Age  Education Urban   US  Profit
# 0   42         17   Yes  Yes     -47
# 1   65         10   Yes  Yes     -35
# 2   59         12   Yes  Yes     -45

# %%
company.Sales.mean()
# Out:
# 7.496325

# %%
company.columns
# Out:
# Index(['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price',
#        'Age', 'Education', 'Urban', 'US', 'Profit'],
#       dtype='object')

# %%
company.Income.min()
# Out:
# 21

# %%
company.Income.max()
# Out:
# 120

# %%
company.Advertising.max()
# Out:
# 29

# %%
company.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0   9.50        138      73           11         276    120   42         17
# 1  11.22        111      48           16         260     83   65         10
# 2  10.06        113      35           10         269     80   59         12
# 3   7.40        117     100            4         466     97   55         14
# 4   4.15        141      64            3         340    128   38         13
#
#   Urban   US  Profit
# 0   Yes  Yes     -47
# 1   Yes  Yes     -35
# 2   Yes  Yes     -45
# 3   Yes  Yes       3
# 4   Yes   No     -64

# %%
company.Urban.describe()
# Out:
# count     400
# unique      2
# top       Yes
# freq      282
# Name: Urban, dtype: object

# %%
company.Urban.value_counts()
# Out:
# Yes    282
# No     118
# Name: Urban, dtype: int64

# %%
company.Urban.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
company.Income.hist()

# %%
type(company)  #DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
sales = company.Sales

# %%
type(sales) #Series is a 1D Data Structure in Pandas
# Out:
# pandas.core.series.Series

# %%
value = company.iloc[2,2]

# %%
type(value)
# Out:
# numpy.int64

# %%
company.corr() #Correlation between two parameters
# Out:
#                 Sales  CompPrice    Income  Advertising  Population     Price  \
# Sales        1.000000   0.064079  0.151951     0.269507    0.050471 -0.444951
# CompPrice    0.064079   1.000000 -0.080653    -0.024199   -0.094707  0.584848
# Income       0.151951  -0.080653  1.000000     0.058995   -0.007877 -0.056698
# Advertising  0.269507  -0.024199  0.058995     1.000000    0.265652  0.044537
# Population   0.050471  -0.094707 -0.007877     0.265652    1.000000 -0.012144
# Price       -0.444951   0.584848 -0.056698     0.044537   -0.012144  1.000000
# Age         -0.231815  -0.100239 -0.004670    -0.004557   -0.042663 -0.102177
# Education   -0.051955   0.025197 -0.056855    -0.033594   -0.106378  0.011747
# Profit       0.392565  -0.427526  0.778587     0.015837    0.001781 -0.670672
#
#                   Age  Education    Profit
# Sales       -0.231815  -0.051955  0.392565
# CompPrice   -0.100239   0.025197 -0.427526
# Income      -0.004670  -0.056855  0.778587
# ...

# %%
company.std()
# Out:
# Sales            2.824115
# CompPrice       15.334512
# Income          27.986037
# Advertising      6.650364
# Population     147.376436
# Price           23.676664
# Age             16.200297
# Education        2.620528
# Profit          37.668833
# dtype: float64

# %%
company.var()
# Out:
# Sales              7.975626
# CompPrice        235.147243
# Income           783.218239
# Advertising       44.227343
# Population     21719.813935
# Price            560.584436
# Age              262.449618
# Education          6.867168
# Profit          1418.940946
# dtype: float64

# %%
company.median()
# Out:
# Sales            7.49
# CompPrice      125.00
# Income          69.00
# Advertising      5.00
# Population     272.00
# Price          117.00
# Age             54.50
# Education       14.00
# Profit         -48.00
# dtype: float64

# %%
company.mode()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price   Age  Education  \
# 0    7.8      121.0    69.0          0.0         125  120.0  62.0       12.0
# 1    NaN        NaN     NaN          NaN         148  128.0   NaN       17.0
# 2    NaN        NaN     NaN          NaN         170    NaN   NaN        NaN
# 3    NaN        NaN     NaN          NaN         220    NaN   NaN        NaN
# 4    NaN        NaN     NaN          NaN         237    NaN   NaN        NaN
# 5    NaN        NaN     NaN          NaN         276    NaN   NaN        NaN
# 6    NaN        NaN     NaN          NaN         497    NaN   NaN        NaN
#
#   Urban   US  Profit
# 0   Yes  Yes   -64.0
# 1   NaN  NaN   -45.0
# 2   NaN  NaN   -26.0
# 3   NaN  NaN     NaN
# 4   NaN  NaN     NaN
# 5   NaN  NaN     NaN
# 6   NaN  NaN     NaN

# %%
company.groupby(company.Urban).mean()
# Out:
#           Sales   CompPrice     Income  Advertising  Population       Price  \
# Urban
# No     7.563559  123.398305  67.016949     6.203390  276.677966  114.076271
# Yes    7.468191  125.634752  69.343972     6.815603  259.886525  116.514184
#
#              Age  Education     Profit
# Urban
# No     52.610169  14.033898 -47.059322
# Yes    53.620567  13.843972 -47.170213

# %%
dates = pd.date_range('20200409', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2020-04-09', '2020-04-10', '2020-04-11', '2020-04-12',
#                '2020-04-13', '2020-04-14'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np

# %%
np.random.rand(10,4)
# Out:
# array([[0.74742478, 0.16853232, 0.04900121, 0.80387497],
#        [0.38977982, 0.8951808 , 0.01871888, 0.89526224],
#        [0.02748791, 0.79392774, 0.03178833, 0.27662333],
#        [0.50079341, 0.50426087, 0.97833407, 0.09840296],
#        [0.40108055, 0.7245967 , 0.63751277, 0.46967968],
#        [0.8057337 , 0.20162351, 0.7600321 , 0.10323772],
#        [0.56328089, 0.81492997, 0.72004947, 0.82428877],
#        [0.72533994, 0.19099346, 0.00600673, 0.21631093],
#        [0.695729  , 0.58150487, 0.22689283, 0.51082216],
#        [0.85903415, 0.73127387, 0.37832499, 0.37055475]])

# %%
import numpy as np
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2020-04-09  0.151584 -1.312412 -1.211863  1.547029
# 2020-04-10  0.157917 -1.377428 -0.238525 -0.871935
# 2020-04-11 -0.933523  0.778517  0.031255 -0.915264
# 2020-04-12 -0.836101  0.449227 -0.790107  0.423147
# 2020-04-13  0.729835  0.956436 -0.234475  0.237740
# 2020-04-14 -0.541263 -2.282889 -0.733935  0.979393

# %%
df.loc[dates[0]]
# Out:
# A    0.151584
# B   -1.312412
# C   -1.211863
# D    1.547029
# Name: 2020-04-09 00:00:00, dtype: float64

# %%
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2020-04-09  0.151584 -1.312412
# 2020-04-10  0.157917 -1.377428
# 2020-04-11 -0.933523  0.778517
# 2020-04-12 -0.836101  0.449227
# 2020-04-13  0.729835  0.956436
# 2020-04-14 -0.541263 -2.282889

# %%
df.loc['20200409':'20200412', ['A', 'D']]
# Out:
#                    A         D
# 2020-04-09  0.151584  1.547029
# 2020-04-10  0.157917 -0.871935
# 2020-04-11 -0.933523 -0.915264
# 2020-04-12 -0.836101  0.423147

# %%
df.A > 0
# Out:
#                    A         B         C         D
# 2020-04-09  0.151584 -1.312412 -1.211863  1.547029
# 2020-04-10  0.157917 -1.377428 -0.238525 -0.871935
# 2020-04-13  0.729835  0.956436 -0.234475  0.237740

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2013-01-02  0.500905  1.606842  2.592092  0.506440
# 2013-01-04  0.649388 -0.666898 -0.495326  0.154157
# 2013-01-06  1.013547  1.064590  0.100223  0.510346

# %%
company[company.Sales>8]
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0     9.50        138      73           11         276    120   42         17
# 1    11.22        111      48           16         260     83   65         10
# 2    10.06        113      35           10         269     80   59         12
# 5    10.81        124     113           13         501     72   78         16
# 7    11.85        136      81           15         425    120   67         10
# ..     ...        ...     ...          ...         ...    ...  ...        ...
# 387   8.67        142      73           14         238    115   73         14
# 388   8.14        135      89           11         245     78   79         16
# 389   8.44        128      42            8         328    107   35         12
# 395  12.57        138     108           17         203    128   33         14
# 399   9.71        134      37            0          27    120   49         16
#
#     Urban   US  Profit
# ...

# %%
company[['Sales','Income']]
# Out:
#      Sales  Income
# 0     9.50      73
# 1    11.22      48
# 2    10.06      35
# 3     7.40     100
# 4     4.15      64
# ..     ...     ...
# 395  12.57     108
# 396   6.14      23
# 397   7.41      26
# 398   5.94      79
# 399   9.71      37
#
# [400 rows x 2 columns]
